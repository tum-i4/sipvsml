# %%
import pandas as pd

# %%
df = pd.read_csv('../source/best_val_results.csv', encoding='utf-8')

# %%
df
# Out:
#             obfs flag  precision    recall        f1  accuracy
# 0            BCF  CFI   1.000000  1.000000  1.000000  1.000000
# 1            BCF   OH   1.000000  1.000000  1.000000  1.000000
# 2            BCF   SC   0.818182  1.000000  0.900000  0.939394
# 3       BCF-FLAs  CFI   1.000000  1.000000  1.000000  1.000000
# 4       BCF-FLAs   OH   1.000000  1.000000  1.000000  1.000000
# 5       BCF-FLAs   SC   1.000000  0.250000  0.400000  0.892857
# 6   BCF-FLAs-SUB  CFI   1.000000  1.000000  1.000000  1.000000
# 7   BCF-FLAs-SUB   OH   1.000000  1.000000  1.000000  1.000000
# 8   BCF-FLAs-SUB   SC   0.666667  0.666667  0.666667  0.916667
# 9        BCF-SUB  CFI   1.000000  1.000000  1.000000  1.000000
# 10       BCF-SUB   OH   0.833333  1.000000  0.909091  0.965517
# 11       BCF-SUB   SC   1.000000  1.000000  1.000000  1.000000
# 12  BCF-SUB-FLAs  CFI   1.000000  1.000000  1.000000  1.000000
# 13  BCF-SUB-FLAs   OH   0.800000  1.000000  0.888889  0.916667
# ...
