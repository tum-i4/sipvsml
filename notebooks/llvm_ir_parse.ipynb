# %%
import argparse
import itertools
import os
import pathlib
import subprocess
from collections import defaultdict
import json

from tqdm import tqdm
import pandas as pd

# %%
def get_bc_dirs(labeled_bc_dir):
    for sub_folder in ['mibench-cov', 'simple-cov']:
        for data_dir in (labeled_bc_dir / sub_folder).iterdir():
            yield data_dir


def get_all_bc_files(labeled_bc_dir):
    for data_dir in get_bc_dirs(labeled_bc_dir):
        for file in data_dir.iterdir():
            if file.name.endswith('.bc'):
                yield file


def read_instructions(file_path):
    with open(file_path) as inp:
        return [line.strip() for line in inp if line.strip() != '']


def split_blocks(g_instructions):
    buff = []
    for instruction in g_instructions:
        buff.append(instruction)
        if instruction.startswith('br') or instruction.startswith('ret') or instruction.startswith('unreachable'):
            yield buff
            buff = []


def parse_ir_instructions(block_text):
    res = [x.strip() for x in block_text.strip().split('|.|') if x.strip() != '']
    res = [x for x in res if not (x.startswith('%.reg2mem') or x.startswith('%"reg2mem'))]
    return res


def map_general_instructions(bc_dir, df):
    new_column = []
    for bc_name, p_df in df.groupby('program'):
        res = []
        g_instructions = read_instructions(bc_dir / bc_name.replace('.bc', '.gin'))
        block_g_instructions = list(split_blocks(g_instructions))
        block_ir_instructions = list(map(parse_ir_instructions, p_df['w_63']))
        ii = 0
        ig = 0
        while ii < len(block_ir_instructions):
            ir_instr = block_ir_instructions[ii]
            g_instr = block_g_instructions[ig]
            if ir_instr[0] == 'unreachable':
                res.append(ir_instr)
                ii += 1
                ir_instr = block_ir_instructions[ii]
                while len(ir_instr) != len(g_instr):
                    ig += 1
                    g_instr = block_g_instructions[ig]

            assert len(ir_instr) - len(g_instr) <= 1

            res.append(g_instr)
            ii += 1
            ig += 1
        new_column.append(res)
    res = flatten(new_column)
    return res


def flatten(a_list):
    return list(itertools.chain.from_iterable(a_list))


def update_block_df(bc_dir, df):
    df['w_64'] = map_general_instructions(bc_dir, df)


def update_block_files(labeled_bc_dir):
    for bc_dir in get_bc_dirs(labeled_bc_dir):
        blocks_file = bc_dir / 'blocks.csv'
        column_names = ['uid'] + ['w_{}'.format(ii) for ii in range(64)] + ['program'] + ['subject']
        df = pd.read_csv(
            blocks_file, lineterminator='\r', sep=';', header=None,
            index_col=False, dtype={'uid': object}, names=column_names
        ).reset_index()
        update_block_df(bc_dir, df)

# %%
blocks_file = pathlib.Path('/media/nika/TOSHIBA EXT/paperback/LABELED-BCs/simple-cov/NONE/blocks.csv')

# %%
column_names = ['uid'] + ['w_{}'.format(ii) for ii in range(64)] + ['program'] + ['subject']

df = pd.read_csv(
    blocks_file, lineterminator='\r', sep=';', header=None,
    index_col=False, dtype={'uid': object}, names=column_names
)

# %%
a_none_df = df[df['program'] == 'anagram-NONE.bc']
update_block_df(blocks_file.parent, a_none_df)
anagram_none_ir, anagram_none_gin = list(a_none_df['w_63']), list(a_none_df['w_64'])
# Out:
# <ipython-input-224-640b29d72566>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['w_64'] = map_general_instructions(bc_dir, df)

# %%
a_oh_df = df[df['program'] == 'anagram-OH-NONE.bc']
update_block_df(blocks_file.parent, a_oh_df)
anagram_oh_ir, anagram_oh_gin = list(a_oh_df['w_63']), list(a_oh_df['w_64'])
# Out:
# <ipython-input-224-640b29d72566>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['w_64'] = map_general_instructions(bc_dir, df)

# %%
len(anagram_oh_ir), len(anagram_oh_gin)
# Out:
# (108, 108)

# %%
def read_vocab(file_path):
    with open(file_path) as inp:
        res = {}
        for line in map(str.strip, inp):
            if line != '':
                key, val = line.split(':')
                res[key] = json.loads(val.strip(','))
        return res

# %%
vocab = read_vocab('seedEmbeddingVocab-300-llvm10.txt')

# %%
def parse_ir_cmd(text):
    if ' = ' in text:
        text = text.split(' = ')[1]
    return text.split()[0]

# %%
def get_test_samples():
    for irs, gis in zip(map(parse_ir_instructions, anagram_oh_ir), anagram_oh_gin):
        for i, gi in zip(irs, gis):
            yield i, gi
    
    for irs, gis in zip(map(parse_ir_instructions, anagram_none_ir), anagram_none_gin):
        for i, gi in zip(irs, gis):
            yield i, gi

# %%
all_commands = []

for i, gi in get_test_samples():
    ir_cmd = parse_ir_cmd(i)
    all_commands.append(ir_cmd)
    if ir_cmd != gi.split()[0]:
        print(ir_cmd, '------', gi.split()[0])

print(set(all_commands))
# Out:
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# br ------ unreachable
# {'ret', 'store', 'br', 'icmp', 'unreachable', 'getelementptr', 'call', 'xor', 'sext', 'zext', 'bitcast', 'add', 'load', 'alloca', 'sub'}

# %%
dt = []

for i, gi in get_test_samples():
    if ' = ' in i:
        i = i.split(' = ')[1]
    print(i, '------', gi)
# Out:
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# call void @oh_path_functions() ------ call  voidTy  function
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash4, align 8 ------ store  voidTy  constant  pointer
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash3, align 8 ------ store  voidTy  constant  pointer
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash2, align 8 ------ store  voidTy  constant  pointer
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash, align 8 ------ store  voidTy  constant  pointer
# alloca i32, align 4, !input_indep_block !33, !input_dep_instr !34, !data_dep_instr !35 ------ alloca  pointerTy  constant
# alloca i32, align 4, !input_dep_instr !34, !data_dep_instr !35 ------ alloca  pointerTy  constant
# alloca i8**, align 8, !input_dep_instr !34, !data_dep_instr !35 ------ alloca  pointerTy  constant
# alloca i8*, align 8, !input_dep_instr !34, !data_dep_instr !35 ------ alloca  pointerTy  constant
# alloca i8*, align 8, !input_dep_instr !34, !data_dep_instr !35 ------ alloca  pointerTy  constant
# alloca i32, align 4, !input_dep_instr !34, !data_dep_instr !35 ------ alloca  pointerTy  constant
# alloca i64, align 8, !input_dep_instr !34, !data_dep_instr !35 ------ alloca  pointerTy  constant
# store i64* @0, i64** %7, align 8 ------ store  voidTy  pointer  pointer
# store i64 1000000000000, i64* %8, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %7, align 8 ------ load  pointerTy  pointer
# load i64, i64* %40, align 8 ------ load  integerTy  pointer
# load i64, i64* %8, align 8 ------ load  integerTy  pointer
# icmp ne i64 %41, %42, !oh_verify !36 ------ icmp  integerTy  variable  variable
# br i1 %43, label %44, label %assert.1.exit ------ br  voidTy  variable  label  label
# call void @exit(i32 1) #5 ------ call  voidTy  constant  function
# br label %UnifiedUnreachableBlock ------ unreachable  voidTy
# store i32 0, i32* %33, align 4, !input_indep_instr !37, !data_indep_instr !38 ------ store  voidTy  constant  pointer
# load i32, i32* %33 ------ load  integerTy  pointer
# zext i32 %45 to i64 ------ zext  integerTy  variable
# store i64* @0, i64** %3, align 8 ------ store  voidTy  pointer  pointer
# store i64 %46, i64* %4, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %3, align 8 ------ load  pointerTy  pointer
# load i64, i64* %47, align 8 ------ load  integerTy  pointer
# load i64, i64* %4, align 8 ------ load  integerTy  pointer
# xor i64 %48, %49 ------ xor  integerTy  variable  variable
# load i64*, i64** %3, align 8 ------ load  pointerTy  pointer
# store i64 %50, i64* %51, align 8 ------ store  voidTy  variable  pointer
# store i32 %0, i32* %34, align 4, !input_dep_instr !34, !data_dep_instr !35, !argument_dep_instr !39 ------ store  voidTy  variable  pointer
# store i8** %1, i8*** %35, align 8, !input_dep_instr !34, !data_dep_instr !35, !argument_dep_instr !39 ------ store  voidTy  pointer  pointer
# load i32, i32* %34, align 4, !input_dep_instr !34, !data_dep_instr !35, !argument_dep_instr !39 ------ load  integerTy  pointer
# icmp slt i32 %52, 3, !input_dep_instr !34, !data_dep_instr !35, !argument_dep_instr !39 ------ icmp  integerTy  variable  constant
# zext i1 %53 to i64 ------ zext  integerTy  variable
# store i64* %local_hash, i64** %5, align 8 ------ store  voidTy  pointer  pointer
# store i64 %54, i64* %6, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %5, align 8 ------ load  pointerTy  pointer
# load i64, i64* %55, align 8 ------ load  integerTy  pointer
# load i64, i64* %6, align 8 ------ load  integerTy  pointer
# add nsw i64 %56, %57 ------ add  integerTy  variable  variable
# load i64*, i64** %5, align 8 ------ load  pointerTy  pointer
# store i64 %58, i64* %59, align 8 ------ store  voidTy  variable  pointer
# br i1 %53, label %60, label %74, !prof !40, !input_dep_instr !34, !data_dep_instr !35, !argument_dep_instr !39 ------ br  voidTy  variable  label  label
# store i32 1, i32* %33, align 4, !data_indep_instr !38, !argument_dep_instr !39, !input_dep_block !41, !control_dep_instr !42 ------ store  voidTy  constant  pointer
# load i32, i32* %33 ------ load  integerTy  pointer
# zext i32 %61 to i64 ------ zext  integerTy  variable
# store i64* %local_hash, i64** %19, align 8 ------ store  voidTy  pointer  pointer
# store i64 %62, i64* %20, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %19, align 8 ------ load  pointerTy  pointer
# load i64, i64* %63, align 8 ------ load  integerTy  pointer
# load i64, i64* %20, align 8 ------ load  integerTy  pointer
# add nsw i64 %64, %65 ------ add  integerTy  variable  variable
# load i64*, i64** %19, align 8 ------ load  pointerTy  pointer
# store i64 %66, i64* %67, align 8 ------ store  voidTy  variable  pointer
# load i64, i64* %local_hash ------ load  integerTy  pointer
# store i64 %68, i64* @1 ------ store  voidTy  variable  pointer
# store i64* @1, i64** %31, align 8 ------ store  voidTy  pointer  pointer
# store i64 2000000000000, i64* %32, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %31, align 8 ------ load  pointerTy  pointer
# load i64, i64* %69, align 8 ------ load  integerTy  pointer
# load i64, i64* %32, align 8 ------ load  integerTy  pointer
# icmp ne i64 %70, %71, !oh_verify !36 ------ icmp  integerTy  variable  variable
# br i1 %72, label %73, label %assert.exit ------ br  voidTy  variable  label  label
# call void @exit(i32 1) #5 ------ call  voidTy  constant  function
# br label %UnifiedUnreachableBlock ------ unreachable  voidTy
# br label %126, !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ br  voidTy  label
# load i8**, i8*** %35, align 8, !data_dep_instr !35, !argument_dep_instr !39, !input_dep_block !41, !control_dep_instr !42 ------ load  pointerTy  pointer
# getelementptr inbounds i8*, i8** %75, i64 1, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ getelementptr  pointerTy  pointer  constant
# load i8*, i8** %76, align 8, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ load  pointerTy  pointer
# store i8* %77, i8** %36, align 8, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ store  voidTy  pointer  pointer
# load i8**, i8*** %35, align 8, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ load  pointerTy  pointer
# getelementptr inbounds i8*, i8** %78, i64 2, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ getelementptr  pointerTy  pointer  constant
# load i8*, i8** %79, align 8, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ load  pointerTy  pointer
# store i8* %80, i8** %37, align 8, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ store  voidTy  pointer  pointer
# load i8*, i8** %36, align 8, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ load  pointerTy  pointer
# load i8*, i8** %37, align 8, !data_dep_instr !35, !argument_dep_instr !39, !control_dep_instr !42 ------ load  pointerTy  pointer
# call i32 @check_anagram(i8* %81, i8* %82), !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ call  integerTy  pointer  pointer  function
# store i32 %83, i32* %38, align 4, !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ store  voidTy  variable  pointer
# load i32, i32* %38, align 4, !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ load  integerTy  pointer
# icmp eq i32 %84, 1, !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ icmp  integerTy  variable  constant
# zext i1 %85 to i64 ------ zext  integerTy  variable
# store i64* %local_hash2, i64** %17, align 8 ------ store  voidTy  pointer  pointer
# store i64 %86, i64* %18, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %17, align 8 ------ load  pointerTy  pointer
# load i64, i64* %87, align 8 ------ load  integerTy  pointer
# load i64, i64* %18, align 8 ------ load  integerTy  pointer
# add nsw i64 %88, %89 ------ add  integerTy  variable  variable
# load i64*, i64** %17, align 8 ------ load  pointerTy  pointer
# store i64 %90, i64* %91, align 8 ------ store  voidTy  variable  pointer
# zext i1 %85 to i64 ------ zext  integerTy  variable
# store i64* %local_hash4, i64** %15, align 8 ------ store  voidTy  pointer  pointer
# store i64 %92, i64* %16, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %15, align 8 ------ load  pointerTy  pointer
# load i64, i64* %93, align 8 ------ load  integerTy  pointer
# load i64, i64* %16, align 8 ------ load  integerTy  pointer
# add nsw i64 %94, %95 ------ add  integerTy  variable  variable
# load i64*, i64** %15, align 8 ------ load  pointerTy  pointer
# store i64 %96, i64* %97, align 8 ------ store  voidTy  variable  pointer
# br i1 %85, label %98, label %105, !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ br  voidTy  variable  label  label
# call void @main0(i8** %37, i8** %36), !data_indep_instr !38, !argument_dep_instr !39, !input_dep_block !41, !control_dep_instr !42 ------ call  voidTy  pointer  pointer  function
# load i64, i64* %local_hash2 ------ load  integerTy  pointer
# store i64 %99, i64* @1 ------ store  voidTy  variable  pointer
# store i64* @1, i64** %29, align 8 ------ store  voidTy  pointer  pointer
# store i64 5000000000000, i64* %30, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %29, align 8 ------ load  pointerTy  pointer
# load i64, i64* %100, align 8 ------ load  integerTy  pointer
# load i64, i64* %30, align 8 ------ load  integerTy  pointer
# icmp ne i64 %101, %102, !oh_verify !36 ------ icmp  integerTy  variable  variable
# br i1 %103, label %104, label %assert.exit1 ------ br  voidTy  variable  label  label
# call void @exit(i32 1) #5 ------ call  voidTy  constant  function
# br label %UnifiedUnreachableBlock ------ unreachable  voidTy
# br label %112, !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ br  voidTy  label
# call void @main1(i8** %37, i8** %36), !data_indep_instr !38, !argument_dep_instr !39, !input_dep_block !41, !control_dep_instr !42 ------ call  voidTy  pointer  pointer  function
# load i64, i64* %local_hash4 ------ load  integerTy  pointer
# store i64 %106, i64* @1 ------ store  voidTy  variable  pointer
# store i64* @1, i64** %27, align 8 ------ store  voidTy  pointer  pointer
# store i64 7000000000000, i64* %28, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %27, align 8 ------ load  pointerTy  pointer
# load i64, i64* %107, align 8 ------ load  integerTy  pointer
# load i64, i64* %28, align 8 ------ load  integerTy  pointer
# icmp ne i64 %108, %109, !oh_verify !36 ------ icmp  integerTy  variable  variable
# br i1 %110, label %111, label %assert.exit2 ------ br  voidTy  variable  label  label
# call void @exit(i32 1) #5 ------ call  voidTy  constant  function
# br label %UnifiedUnreachableBlock ------ unreachable  voidTy
# br label %112, !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ br  voidTy  label
# store i32 0, i32* %33, align 4, !data_indep_instr !38, !argument_dep_instr !39, !input_dep_block !41, !control_dep_instr !42 ------ store  voidTy  constant  pointer
# load i32, i32* %33 ------ load  integerTy  pointer
# zext i32 %113 to i64 ------ zext  integerTy  variable
# store i64* %local_hash3, i64** %13, align 8 ------ store  voidTy  pointer  pointer
# store i64 %114, i64* %14, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %13, align 8 ------ load  pointerTy  pointer
# load i64, i64* %115, align 8 ------ load  integerTy  pointer
# load i64, i64* %14, align 8 ------ load  integerTy  pointer
# add nsw i64 %116, %117 ------ add  integerTy  variable  variable
# load i64*, i64** %13, align 8 ------ load  pointerTy  pointer
# store i64 %118, i64* %119, align 8 ------ store  voidTy  variable  pointer
# load i64, i64* %local_hash3 ------ load  integerTy  pointer
# store i64 %120, i64* @1 ------ store  voidTy  variable  pointer
# store i64* @1, i64** %25, align 8 ------ store  voidTy  pointer  pointer
# store i64 6000000000000, i64* %26, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %25, align 8 ------ load  pointerTy  pointer
# load i64, i64* %121, align 8 ------ load  integerTy  pointer
# load i64, i64* %26, align 8 ------ load  integerTy  pointer
# icmp ne i64 %122, %123, !oh_verify !36 ------ icmp  integerTy  variable  variable
# br i1 %124, label %125, label %assert.exit3 ------ br  voidTy  variable  label  label
# call void @exit(i32 1) #5 ------ call  voidTy  constant  function
# br label %UnifiedUnreachableBlock ------ unreachable  voidTy
# br label %126, !data_indep_instr !38, !argument_dep_instr !39, !control_dep_instr !42 ------ br  voidTy  label
# store i64* @0, i64** %23, align 8 ------ store  voidTy  pointer  pointer
# store i64 3000000000000, i64* %24, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %23, align 8 ------ load  pointerTy  pointer
# load i64, i64* %127, align 8 ------ load  integerTy  pointer
# load i64, i64* %24, align 8 ------ load  integerTy  pointer
# icmp ne i64 %128, %129, !oh_verify !36 ------ icmp  integerTy  variable  variable
# br i1 %130, label %131, label %assert.exit4 ------ br  voidTy  variable  label  label
# call void @exit(i32 1) #5 ------ call  voidTy  constant  function
# br label %UnifiedUnreachableBlock ------ unreachable  voidTy
# load i32, i32* %33, align 4, !input_indep_block !33, !input_indep_instr !37, !data_indep_instr !38 ------ load  integerTy  pointer
# zext i32 %132 to i64 ------ zext  integerTy  variable
# store i64* @0, i64** %9, align 8 ------ store  voidTy  pointer  pointer
# store i64 %133, i64* %10, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %9, align 8 ------ load  pointerTy  pointer
# load i64, i64* %134, align 8 ------ load  integerTy  pointer
# load i64, i64* %10, align 8 ------ load  integerTy  pointer
# xor i64 %135, %136 ------ xor  integerTy  variable  variable
# load i64*, i64** %9, align 8 ------ load  pointerTy  pointer
# store i64 %137, i64* %138, align 8 ------ store  voidTy  variable  pointer
# zext i32 %132 to i64 ------ zext  integerTy  variable
# store i64* @0, i64** %11, align 8 ------ store  voidTy  pointer  pointer
# store i64 %139, i64* %12, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %11, align 8 ------ load  pointerTy  pointer
# load i64, i64* %140, align 8 ------ load  integerTy  pointer
# load i64, i64* %12, align 8 ------ load  integerTy  pointer
# add nsw i64 %141, %142 ------ add  integerTy  variable  variable
# load i64*, i64** %11, align 8 ------ load  pointerTy  pointer
# store i64 %143, i64* %144, align 8 ------ store  voidTy  variable  pointer
# store i64* @0, i64** %21, align 8 ------ store  voidTy  pointer  pointer
# store i64 4000000000000, i64* %22, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %21, align 8 ------ load  pointerTy  pointer
# load i64, i64* %145, align 8 ------ load  integerTy  pointer
# load i64, i64* %22, align 8 ------ load  integerTy  pointer
# icmp ne i64 %146, %147, !oh_verify !36 ------ icmp  integerTy  variable  variable
# br i1 %148, label %149, label %assert.exit5 ------ br  voidTy  variable  label  label
# call void @exit(i32 1) #5 ------ call  voidTy  constant  function
# br label %UnifiedUnreachableBlock ------ unreachable  voidTy
# ret i32 %132, !input_indep_instr !37, !data_indep_instr !38 ------ ret  voidTy  variable
# unreachable ------ unreachable
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64*, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash5, align 8 ------ store  voidTy  constant  pointer
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash4, align 8 ------ store  voidTy  constant  pointer
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash3, align 8 ------ store  voidTy  constant  pointer
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash2, align 8 ------ store  voidTy  constant  pointer
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash1, align 8 ------ store  voidTy  constant  pointer
# alloca i64, align 8 ------ alloca  pointerTy  constant
# store i64 0, i64* %local_hash, align 8 ------ store  voidTy  constant  pointer
# alloca i32, align 4, !input_indep_block !33, !input_dep_instr !34, !data_dep_instr !35, !control_dep_instr !36 ------ alloca  pointerTy  constant
# alloca i8*, align 8, !input_dep_instr !34, !data_dep_instr !35, !control_dep_instr !36 ------ alloca  pointerTy  constant
# alloca i8*, align 8, !input_dep_instr !34, !data_dep_instr !35, !control_dep_instr !36 ------ alloca  pointerTy  constant
# alloca [26 x i32], align 16, !input_dep_instr !34, !data_dep_instr !35, !control_dep_instr !36 ------ alloca  pointerTy  constant
# alloca [26 x i32], align 16, !input_dep_instr !34, !data_dep_instr !35, !control_dep_instr !36 ------ alloca  pointerTy  constant
# alloca i32, align 4, !input_dep_instr !34, !data_dep_instr !35, !control_dep_instr !36 ------ alloca  pointerTy  constant
# store i8* %0, i8** %122, align 8, !input_dep_instr !34, !data_dep_instr !35, !argument_dep_instr !37, !control_dep_instr !36 ------ store  voidTy  pointer  pointer
# store i8* %1, i8** %123, align 8, !input_dep_instr !34, !data_dep_instr !35, !argument_dep_instr !37, !control_dep_instr !36 ------ store  voidTy  pointer  pointer
# bitcast [26 x i32]* %124 to i8*, !input_dep_instr !34, !data_dep_instr !35, !control_dep_instr !36 ------ bitcast  pointerTy  pointer
# call void @llvm.memset.p0i8.i64(i8* align 16 %127, i8 0, i64 104, i1 false), !input_indep_instr !38, !data_indep_instr !39, !control_dep_instr !36 ------ call  voidTy  pointer  constant  constant  constant  function
# store i64* %local_hash5, i64** %107, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %108, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %107, align 8 ------ load  pointerTy  pointer
# load i64, i64* %128, align 8 ------ load  integerTy  pointer
# load i64, i64* %108, align 8 ------ load  integerTy  pointer
# add nsw i64 %129, %130 ------ add  integerTy  variable  variable
# load i64*, i64** %107, align 8 ------ load  pointerTy  pointer
# store i64 %131, i64* %132, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash5, i64** %105, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %106, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %105, align 8 ------ load  pointerTy  pointer
# load i64, i64* %133, align 8 ------ load  integerTy  pointer
# load i64, i64* %106, align 8 ------ load  integerTy  pointer
# add nsw i64 %134, %135 ------ add  integerTy  variable  variable
# load i64*, i64** %105, align 8 ------ load  pointerTy  pointer
# store i64 %136, i64* %137, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash5, i64** %55, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %56, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %55, align 8 ------ load  pointerTy  pointer
# load i64, i64* %138, align 8 ------ load  integerTy  pointer
# load i64, i64* %56, align 8 ------ load  integerTy  pointer
# xor i64 %139, %140 ------ xor  integerTy  variable  variable
# load i64*, i64** %55, align 8 ------ load  pointerTy  pointer
# store i64 %141, i64* %142, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash4, i64** %53, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %54, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %53, align 8 ------ load  pointerTy  pointer
# load i64, i64* %143, align 8 ------ load  integerTy  pointer
# load i64, i64* %54, align 8 ------ load  integerTy  pointer
# xor i64 %144, %145 ------ xor  integerTy  variable  variable
# load i64*, i64** %53, align 8 ------ load  pointerTy  pointer
# store i64 %146, i64* %147, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash4, i64** %103, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %104, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %103, align 8 ------ load  pointerTy  pointer
# load i64, i64* %148, align 8 ------ load  integerTy  pointer
# load i64, i64* %104, align 8 ------ load  integerTy  pointer
# add nsw i64 %149, %150 ------ add  integerTy  variable  variable
# load i64*, i64** %103, align 8 ------ load  pointerTy  pointer
# store i64 %151, i64* %152, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash4, i64** %51, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %52, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %51, align 8 ------ load  pointerTy  pointer
# load i64, i64* %153, align 8 ------ load  integerTy  pointer
# load i64, i64* %52, align 8 ------ load  integerTy  pointer
# xor i64 %154, %155 ------ xor  integerTy  variable  variable
# load i64*, i64** %51, align 8 ------ load  pointerTy  pointer
# store i64 %156, i64* %157, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash3, i64** %101, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %102, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %101, align 8 ------ load  pointerTy  pointer
# load i64, i64* %158, align 8 ------ load  integerTy  pointer
# load i64, i64* %102, align 8 ------ load  integerTy  pointer
# add nsw i64 %159, %160 ------ add  integerTy  variable  variable
# load i64*, i64** %101, align 8 ------ load  pointerTy  pointer
# store i64 %161, i64* %162, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash3, i64** %99, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %100, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %99, align 8 ------ load  pointerTy  pointer
# load i64, i64* %163, align 8 ------ load  integerTy  pointer
# load i64, i64* %100, align 8 ------ load  integerTy  pointer
# add nsw i64 %164, %165 ------ add  integerTy  variable  variable
# load i64*, i64** %99, align 8 ------ load  pointerTy  pointer
# store i64 %166, i64* %167, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash3, i64** %97, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %98, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %97, align 8 ------ load  pointerTy  pointer
# load i64, i64* %168, align 8 ------ load  integerTy  pointer
# load i64, i64* %98, align 8 ------ load  integerTy  pointer
# add nsw i64 %169, %170 ------ add  integerTy  variable  variable
# load i64*, i64** %97, align 8 ------ load  pointerTy  pointer
# store i64 %171, i64* %172, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash2, i64** %49, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %50, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %49, align 8 ------ load  pointerTy  pointer
# load i64, i64* %173, align 8 ------ load  integerTy  pointer
# load i64, i64* %50, align 8 ------ load  integerTy  pointer
# xor i64 %174, %175 ------ xor  integerTy  variable  variable
# load i64*, i64** %49, align 8 ------ load  pointerTy  pointer
# store i64 %176, i64* %177, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash2, i64** %47, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %48, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %47, align 8 ------ load  pointerTy  pointer
# load i64, i64* %178, align 8 ------ load  integerTy  pointer
# load i64, i64* %48, align 8 ------ load  integerTy  pointer
# xor i64 %179, %180 ------ xor  integerTy  variable  variable
# load i64*, i64** %47, align 8 ------ load  pointerTy  pointer
# store i64 %181, i64* %182, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash2, i64** %95, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %96, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %95, align 8 ------ load  pointerTy  pointer
# load i64, i64* %183, align 8 ------ load  integerTy  pointer
# load i64, i64* %96, align 8 ------ load  integerTy  pointer
# add nsw i64 %184, %185 ------ add  integerTy  variable  variable
# load i64*, i64** %95, align 8 ------ load  pointerTy  pointer
# store i64 %186, i64* %187, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash1, i64** %45, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %46, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %45, align 8 ------ load  pointerTy  pointer
# load i64, i64* %188, align 8 ------ load  integerTy  pointer
# load i64, i64* %46, align 8 ------ load  integerTy  pointer
# xor i64 %189, %190 ------ xor  integerTy  variable  variable
# load i64*, i64** %45, align 8 ------ load  pointerTy  pointer
# store i64 %191, i64* %192, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash1, i64** %93, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %94, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %93, align 8 ------ load  pointerTy  pointer
# load i64, i64* %193, align 8 ------ load  integerTy  pointer
# load i64, i64* %94, align 8 ------ load  integerTy  pointer
# add nsw i64 %194, %195 ------ add  integerTy  variable  variable
# load i64*, i64** %93, align 8 ------ load  pointerTy  pointer
# store i64 %196, i64* %197, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash1, i64** %91, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %92, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %91, align 8 ------ load  pointerTy  pointer
# load i64, i64* %198, align 8 ------ load  integerTy  pointer
# load i64, i64* %92, align 8 ------ load  integerTy  pointer
# add nsw i64 %199, %200 ------ add  integerTy  variable  variable
# load i64*, i64** %91, align 8 ------ load  pointerTy  pointer
# store i64 %201, i64* %202, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash, i64** %43, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %44, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %43, align 8 ------ load  pointerTy  pointer
# load i64, i64* %203, align 8 ------ load  integerTy  pointer
# load i64, i64* %44, align 8 ------ load  integerTy  pointer
# xor i64 %204, %205 ------ xor  integerTy  variable  variable
# load i64*, i64** %43, align 8 ------ load  pointerTy  pointer
# store i64 %206, i64* %207, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash, i64** %41, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %42, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %41, align 8 ------ load  pointerTy  pointer
# load i64, i64* %208, align 8 ------ load  integerTy  pointer
# load i64, i64* %42, align 8 ------ load  integerTy  pointer
# xor i64 %209, %210 ------ xor  integerTy  variable  variable
# load i64*, i64** %41, align 8 ------ load  pointerTy  pointer
# store i64 %211, i64* %212, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash, i64** %39, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %40, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %39, align 8 ------ load  pointerTy  pointer
# load i64, i64* %213, align 8 ------ load  integerTy  pointer
# load i64, i64* %40, align 8 ------ load  integerTy  pointer
# xor i64 %214, %215 ------ xor  integerTy  variable  variable
# load i64*, i64** %39, align 8 ------ load  pointerTy  pointer
# store i64 %216, i64* %217, align 8 ------ store  voidTy  variable  pointer
# bitcast [26 x i32]* %125 to i8*, !input_dep_instr !34, !data_dep_instr !35, !control_dep_instr !36 ------ bitcast  pointerTy  pointer
# call void @llvm.memset.p0i8.i64(i8* align 16 %218, i8 0, i64 104, i1 false), !input_indep_instr !38, !data_indep_instr !39, !control_dep_instr !36 ------ call  voidTy  pointer  constant  constant  constant  function
# store i64* %local_hash5, i64** %89, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %90, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %89, align 8 ------ load  pointerTy  pointer
# load i64, i64* %219, align 8 ------ load  integerTy  pointer
# load i64, i64* %90, align 8 ------ load  integerTy  pointer
# add nsw i64 %220, %221 ------ add  integerTy  variable  variable
# load i64*, i64** %89, align 8 ------ load  pointerTy  pointer
# store i64 %222, i64* %223, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash5, i64** %37, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %38, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %37, align 8 ------ load  pointerTy  pointer
# load i64, i64* %224, align 8 ------ load  integerTy  pointer
# load i64, i64* %38, align 8 ------ load  integerTy  pointer
# xor i64 %225, %226 ------ xor  integerTy  variable  variable
# load i64*, i64** %37, align 8 ------ load  pointerTy  pointer
# store i64 %227, i64* %228, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash5, i64** %87, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %88, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %87, align 8 ------ load  pointerTy  pointer
# load i64, i64* %229, align 8 ------ load  integerTy  pointer
# load i64, i64* %88, align 8 ------ load  integerTy  pointer
# add nsw i64 %230, %231 ------ add  integerTy  variable  variable
# load i64*, i64** %87, align 8 ------ load  pointerTy  pointer
# store i64 %232, i64* %233, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash4, i64** %35, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %36, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %35, align 8 ------ load  pointerTy  pointer
# load i64, i64* %234, align 8 ------ load  integerTy  pointer
# load i64, i64* %36, align 8 ------ load  integerTy  pointer
# xor i64 %235, %236 ------ xor  integerTy  variable  variable
# load i64*, i64** %35, align 8 ------ load  pointerTy  pointer
# store i64 %237, i64* %238, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash4, i64** %33, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %34, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %33, align 8 ------ load  pointerTy  pointer
# load i64, i64* %239, align 8 ------ load  integerTy  pointer
# load i64, i64* %34, align 8 ------ load  integerTy  pointer
# xor i64 %240, %241 ------ xor  integerTy  variable  variable
# load i64*, i64** %33, align 8 ------ load  pointerTy  pointer
# store i64 %242, i64* %243, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash4, i64** %85, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %86, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %85, align 8 ------ load  pointerTy  pointer
# load i64, i64* %244, align 8 ------ load  integerTy  pointer
# load i64, i64* %86, align 8 ------ load  integerTy  pointer
# add nsw i64 %245, %246 ------ add  integerTy  variable  variable
# load i64*, i64** %85, align 8 ------ load  pointerTy  pointer
# store i64 %247, i64* %248, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash3, i64** %83, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %84, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %83, align 8 ------ load  pointerTy  pointer
# load i64, i64* %249, align 8 ------ load  integerTy  pointer
# load i64, i64* %84, align 8 ------ load  integerTy  pointer
# add nsw i64 %250, %251 ------ add  integerTy  variable  variable
# load i64*, i64** %83, align 8 ------ load  pointerTy  pointer
# store i64 %252, i64* %253, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash3, i64** %31, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %32, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %31, align 8 ------ load  pointerTy  pointer
# load i64, i64* %254, align 8 ------ load  integerTy  pointer
# load i64, i64* %32, align 8 ------ load  integerTy  pointer
# xor i64 %255, %256 ------ xor  integerTy  variable  variable
# load i64*, i64** %31, align 8 ------ load  pointerTy  pointer
# store i64 %257, i64* %258, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash3, i64** %81, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %82, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %81, align 8 ------ load  pointerTy  pointer
# load i64, i64* %259, align 8 ------ load  integerTy  pointer
# load i64, i64* %82, align 8 ------ load  integerTy  pointer
# add nsw i64 %260, %261 ------ add  integerTy  variable  variable
# load i64*, i64** %81, align 8 ------ load  pointerTy  pointer
# store i64 %262, i64* %263, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash2, i64** %79, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %80, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %79, align 8 ------ load  pointerTy  pointer
# load i64, i64* %264, align 8 ------ load  integerTy  pointer
# load i64, i64* %80, align 8 ------ load  integerTy  pointer
# add nsw i64 %265, %266 ------ add  integerTy  variable  variable
# load i64*, i64** %79, align 8 ------ load  pointerTy  pointer
# store i64 %267, i64* %268, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash2, i64** %77, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %78, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %77, align 8 ------ load  pointerTy  pointer
# load i64, i64* %269, align 8 ------ load  integerTy  pointer
# load i64, i64* %78, align 8 ------ load  integerTy  pointer
# add nsw i64 %270, %271 ------ add  integerTy  variable  variable
# load i64*, i64** %77, align 8 ------ load  pointerTy  pointer
# store i64 %272, i64* %273, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash2, i64** %29, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %30, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %29, align 8 ------ load  pointerTy  pointer
# load i64, i64* %274, align 8 ------ load  integerTy  pointer
# load i64, i64* %30, align 8 ------ load  integerTy  pointer
# xor i64 %275, %276 ------ xor  integerTy  variable  variable
# load i64*, i64** %29, align 8 ------ load  pointerTy  pointer
# store i64 %277, i64* %278, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash1, i64** %75, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %76, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %75, align 8 ------ load  pointerTy  pointer
# load i64, i64* %279, align 8 ------ load  integerTy  pointer
# load i64, i64* %76, align 8 ------ load  integerTy  pointer
# add nsw i64 %280, %281 ------ add  integerTy  variable  variable
# load i64*, i64** %75, align 8 ------ load  pointerTy  pointer
# store i64 %282, i64* %283, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash1, i64** %27, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %28, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %27, align 8 ------ load  pointerTy  pointer
# load i64, i64* %284, align 8 ------ load  integerTy  pointer
# load i64, i64* %28, align 8 ------ load  integerTy  pointer
# xor i64 %285, %286 ------ xor  integerTy  variable  variable
# load i64*, i64** %27, align 8 ------ load  pointerTy  pointer
# store i64 %287, i64* %288, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash1, i64** %25, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %26, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %25, align 8 ------ load  pointerTy  pointer
# load i64, i64* %289, align 8 ------ load  integerTy  pointer
# load i64, i64* %26, align 8 ------ load  integerTy  pointer
# xor i64 %290, %291 ------ xor  integerTy  variable  variable
# load i64*, i64** %25, align 8 ------ load  pointerTy  pointer
# store i64 %292, i64* %293, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash, i64** %73, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %74, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %73, align 8 ------ load  pointerTy  pointer
# load i64, i64* %294, align 8 ------ load  integerTy  pointer
# load i64, i64* %74, align 8 ------ load  integerTy  pointer
# add nsw i64 %295, %296 ------ add  integerTy  variable  variable
# load i64*, i64** %73, align 8 ------ load  pointerTy  pointer
# store i64 %297, i64* %298, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash, i64** %23, align 8 ------ store  voidTy  pointer  pointer
# store i64 104, i64* %24, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %23, align 8 ------ load  pointerTy  pointer
# load i64, i64* %299, align 8 ------ load  integerTy  pointer
# load i64, i64* %24, align 8 ------ load  integerTy  pointer
# xor i64 %300, %301 ------ xor  integerTy  variable  variable
# load i64*, i64** %23, align 8 ------ load  pointerTy  pointer
# store i64 %302, i64* %303, align 8 ------ store  voidTy  variable  pointer
# store i64* %local_hash, i64** %21, align 8 ------ store  voidTy  pointer  pointer
# store i64 0, i64* %22, align 8 ------ store  voidTy  constant  pointer
# load i64*, i64** %21, align 8 ------ load  pointerTy  pointer
# load i64, i64* %304, align 8 ------ load  integerTy  pointer
# load i64, i64* %22, align 8 ------ load  integerTy  pointer
# xor i64 %305, %306 ------ xor  integerTy  variable  variable
# load i64*, i64** %21, align 8 ------ load  pointerTy  pointer
# store i64 %307, i64* %308, align 8 ------ store  voidTy  variable  pointer
# store i32 0, i32* %126, align 4, !input_indep_instr !38, !data_indep_instr !39, !control_dep_instr !36 ------ store  voidTy  constant  pointer
# load i32, i32* %126 ------ load  integerTy  pointer
# zext i32 %309 to i64 ------ zext  integerTy  variable
# store i64* %local_hash5, i64** %19, align 8 ------ store  voidTy  pointer  pointer
# store i64 %310, i64* %20, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %19, align 8 ------ load  pointerTy  pointer
# load i64, i64* %311, align 8 ------ load  integerTy  pointer
# load i64, i64* %20, align 8 ------ load  integerTy  pointer
# xor i64 %312, %313 ------ xor  integerTy  variable  variable
# load i64*, i64** %19, align 8 ------ load  pointerTy  pointer
# store i64 %314, i64* %315, align 8 ------ store  voidTy  variable  pointer
# load i32, i32* %126 ------ load  integerTy  pointer
# zext i32 %316 to i64 ------ zext  integerTy  variable
# store i64* %local_hash4, i64** %71, align 8 ------ store  voidTy  pointer  pointer
# store i64 %317, i64* %72, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %71, align 8 ------ load  pointerTy  pointer
# load i64, i64* %318, align 8 ------ load  integerTy  pointer
# load i64, i64* %72, align 8 ------ load  integerTy  pointer
# add nsw i64 %319, %320 ------ add  integerTy  variable  variable
# load i64*, i64** %71, align 8 ------ load  pointerTy  pointer
# store i64 %321, i64* %322, align 8 ------ store  voidTy  variable  pointer
# load i32, i32* %126 ------ load  integerTy  pointer
# zext i32 %323 to i64 ------ zext  integerTy  variable
# store i64* %local_hash3, i64** %17, align 8 ------ store  voidTy  pointer  pointer
# store i64 %324, i64* %18, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %17, align 8 ------ load  pointerTy  pointer
# load i64, i64* %325, align 8 ------ load  integerTy  pointer
# load i64, i64* %18, align 8 ------ load  integerTy  pointer
# xor i64 %326, %327 ------ xor  integerTy  variable  variable
# load i64*, i64** %17, align 8 ------ load  pointerTy  pointer
# store i64 %328, i64* %329, align 8 ------ store  voidTy  variable  pointer
# load i32, i32* %126 ------ load  integerTy  pointer
# zext i32 %330 to i64 ------ zext  integerTy  variable
# store i64* %local_hash2, i64** %69, align 8 ------ store  voidTy  pointer  pointer
# store i64 %331, i64* %70, align 8 ------ store  voidTy  variable  pointer
# load i64*, i64** %69, align 8 ------ load  pointerTy  pointer
# ...
# store i8** %1, i8*** %5, align 8, !input_dep_instr !5, !data_dep_instr !6, !argument_dep_instr !9 ------ store  voidTy  pointer  pointer
# load i32, i32* %4, align 4, !input_dep_instr !5, !data_dep_instr !6, !argument_dep_instr !9 ------ load  integerTy  pointer
# icmp slt i32 %10, 3, !input_dep_instr !5, !data_dep_instr !6, !argument_dep_instr !9 ------ icmp  integerTy  variable  constant
# br i1 %11, label %12, label %13, !input_dep_instr !5, !data_dep_instr !6, !argument_dep_instr !9 ------ br  voidTy  variable  label  label
# store i32 1, i32* %3, align 4, !data_indep_instr !8, !argument_dep_instr !9, !input_dep_block !10, !control_dep_instr !11 ------ store  voidTy  constant  pointer
# br label %28, !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ br  voidTy  label
# load i8**, i8*** %5, align 8, !data_dep_instr !6, !argument_dep_instr !9, !input_dep_block !10, !control_dep_instr !11 ------ load  pointerTy  pointer
# getelementptr inbounds i8*, i8** %14, i64 1, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ getelementptr  pointerTy  pointer  constant
# load i8*, i8** %15, align 8, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ load  pointerTy  pointer
# store i8* %16, i8** %6, align 8, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ store  voidTy  pointer  pointer
# load i8**, i8*** %5, align 8, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ load  pointerTy  pointer
# getelementptr inbounds i8*, i8** %17, i64 2, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ getelementptr  pointerTy  pointer  constant
# load i8*, i8** %18, align 8, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ load  pointerTy  pointer
# store i8* %19, i8** %7, align 8, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ store  voidTy  pointer  pointer
# load i8*, i8** %6, align 8, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ load  pointerTy  pointer
# load i8*, i8** %7, align 8, !data_dep_instr !6, !argument_dep_instr !9, !control_dep_instr !11 ------ load  pointerTy  pointer
# call i32 @check_anagram(i8* %20, i8* %21), !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ call  integerTy  pointer  pointer  function
# store i32 %22, i32* %8, align 4, !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ store  voidTy  variable  pointer
# load i32, i32* %8, align 4, !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ load  integerTy  pointer
# icmp eq i32 %23, 1, !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ icmp  integerTy  variable  constant
# br i1 %24, label %25, label %26, !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ br  voidTy  variable  label  label
# call void @main0(i8** %7, i8** %6), !data_indep_instr !8, !argument_dep_instr !9, !input_dep_block !10, !control_dep_instr !11 ------ call  voidTy  pointer  pointer  function
# br label %27, !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ br  voidTy  label
# call void @main1(i8** %7, i8** %6), !data_indep_instr !8, !argument_dep_instr !9, !input_dep_block !10, !control_dep_instr !11 ------ call  voidTy  pointer  pointer  function
# br label %27, !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ br  voidTy  label
# store i32 0, i32* %3, align 4, !data_indep_instr !8, !argument_dep_instr !9, !input_dep_block !10, !control_dep_instr !11 ------ store  voidTy  constant  pointer
# br label %28, !data_indep_instr !8, !argument_dep_instr !9, !control_dep_instr !11 ------ br  voidTy  label
# load i32, i32* %3, align 4, !input_indep_block !4, !input_indep_instr !7, !data_indep_instr !8 ------ load  integerTy  pointer
# ret i32 %29, !input_indep_instr !7, !data_indep_instr !8 ------ ret  voidTy  variable
# alloca i32, align 4, !input_indep_block !4, !input_dep_instr !5, !data_dep_instr !6, !control_dep_instr !7 ------ alloca  pointerTy  constant
# alloca i8*, align 8, !input_dep_instr !5, !data_dep_instr !6, !control_dep_instr !7 ------ alloca  pointerTy  constant
# alloca i8*, align 8, !input_dep_instr !5, !data_dep_instr !6, !control_dep_instr !7 ------ alloca  pointerTy  constant
# alloca [26 x i32], align 16, !input_dep_instr !5, !data_dep_instr !6, !control_dep_instr !7 ------ alloca  pointerTy  constant
# alloca [26 x i32], align 16, !input_dep_instr !5, !data_dep_instr !6, !control_dep_instr !7 ------ alloca  pointerTy  constant
# alloca i32, align 4, !input_dep_instr !5, !data_dep_instr !6, !control_dep_instr !7 ------ alloca  pointerTy  constant
# store i8* %0, i8** %4, align 8, !input_dep_instr !5, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ store  voidTy  pointer  pointer
# store i8* %1, i8** %5, align 8, !input_dep_instr !5, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ store  voidTy  pointer  pointer
# bitcast [26 x i32]* %6 to i8*, !input_dep_instr !5, !data_dep_instr !6, !control_dep_instr !7 ------ bitcast  pointerTy  pointer
# call void @llvm.memset.p0i8.i64(i8* align 16 %9, i8 0, i64 104, i1 false), !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ call  voidTy  pointer  constant  constant  constant  function
# bitcast [26 x i32]* %7 to i8*, !input_dep_instr !5, !data_dep_instr !6, !control_dep_instr !7 ------ bitcast  pointerTy  pointer
# call void @llvm.memset.p0i8.i64(i8* align 16 %10, i8 0, i64 104, i1 false), !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ call  voidTy  pointer  constant  constant  constant  function
# store i32 0, i32* %8, align 4, !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ store  voidTy  constant  pointer
# br label %11, !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ br  voidTy  label
# load i8*, i8** %4, align 8, !data_dep_instr !6, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ load  pointerTy  pointer
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i32 %13 to i64, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# getelementptr inbounds i8, i8* %12, i64 %14, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ getelementptr  pointerTy  pointer  variable
# load i8, i8* %15, align 1, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i8 %16 to i32, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# icmp ne i32 %17, 0, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ icmp  integerTy  variable  constant
# br i1 %18, label %19, label %33, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  variable  label  label
# load i8*, i8** %4, align 8, !data_dep_instr !6, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ load  pointerTy  pointer
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i32 %21 to i64, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# getelementptr inbounds i8, i8* %20, i64 %22, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ getelementptr  pointerTy  pointer  variable
# load i8, i8* %23, align 1, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i8 %24 to i32, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# sub nsw i32 %25, 97, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sub  integerTy  variable  constant
# sext i32 %26 to i64, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# getelementptr inbounds [26 x i32], [26 x i32]* %6, i64 0, i64 %27, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ getelementptr  pointerTy  pointer  constant  variable
# load i32, i32* %28, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# add nsw i32 %29, 1, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ add  integerTy  variable  constant
# store i32 %30, i32* %28, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ store  voidTy  variable  pointer
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# add nsw i32 %31, 1, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ add  integerTy  variable  constant
# store i32 %32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ store  voidTy  variable  pointer
# br label %11, !data_indep_instr !10, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  label
# store i32 0, i32* %8, align 4, !input_indep_block !4, !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ store  voidTy  constant  pointer
# br label %34, !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ br  voidTy  label
# load i8*, i8** %5, align 8, !data_dep_instr !6, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ load  pointerTy  pointer
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i32 %36 to i64, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# getelementptr inbounds i8, i8* %35, i64 %37, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ getelementptr  pointerTy  pointer  variable
# load i8, i8* %38, align 1, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i8 %39 to i32, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# icmp ne i32 %40, 0, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ icmp  integerTy  variable  constant
# br i1 %41, label %42, label %56, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  variable  label  label
# load i8*, i8** %5, align 8, !data_dep_instr !6, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ load  pointerTy  pointer
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i32 %44 to i64, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# getelementptr inbounds i8, i8* %43, i64 %45, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ getelementptr  pointerTy  pointer  variable
# load i8, i8* %46, align 1, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i8 %47 to i32, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# sub nsw i32 %48, 97, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sub  integerTy  variable  constant
# sext i32 %49 to i64, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# getelementptr inbounds [26 x i32], [26 x i32]* %7, i64 0, i64 %50, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ getelementptr  pointerTy  pointer  constant  variable
# load i32, i32* %51, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# add nsw i32 %52, 1, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ add  integerTy  variable  constant
# store i32 %53, i32* %51, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ store  voidTy  variable  pointer
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# add nsw i32 %54, 1, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ add  integerTy  variable  constant
# store i32 %55, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ store  voidTy  variable  pointer
# br label %34, !data_indep_instr !10, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  label
# store i32 0, i32* %8, align 4, !input_indep_block !4, !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ store  voidTy  constant  pointer
# br label %57, !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ br  voidTy  label
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ load  integerTy  pointer
# icmp slt i32 %58, 26, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ icmp  integerTy  variable  constant
# br i1 %59, label %60, label %73, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  variable  label  label
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i32 %61 to i64, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# getelementptr inbounds [26 x i32], [26 x i32]* %6, i64 0, i64 %62, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ getelementptr  pointerTy  pointer  constant  variable
# load i32, i32* %63, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# load i32, i32* %8, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# sext i32 %65 to i64, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ sext  integerTy  variable
# getelementptr inbounds [26 x i32], [26 x i32]* %7, i64 0, i64 %66, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ getelementptr  pointerTy  pointer  constant  variable
# load i32, i32* %67, align 4, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ load  integerTy  pointer
# icmp ne i32 %64, %68, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ icmp  integerTy  variable  variable
# br i1 %69, label %70, label %71, !data_dep_instr !6, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  variable  label  label
# store i32 0, i32* %3, align 4, !data_indep_instr !10, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ store  voidTy  constant  pointer
# br label %74, !data_indep_instr !10, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  label
# br label %72, !data_indep_instr !10, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ br  voidTy  label
# call void @check_anagram0(i32* %8), !data_indep_instr !10, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ call  voidTy  pointer  function
# br label %57, !data_indep_instr !10, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  label
# store i32 1, i32* %3, align 4, !data_indep_instr !10, !argument_dep_instr !8, !input_dep_block !11, !control_dep_instr !7 ------ store  voidTy  constant  pointer
# br label %74, !data_indep_instr !10, !argument_dep_instr !8, !control_dep_instr !7 ------ br  voidTy  label
# load i32, i32* %3, align 4, !input_indep_block !4, !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ load  integerTy  pointer
# ret i32 %75, !input_indep_instr !9, !data_indep_instr !10, !control_dep_instr !7 ------ ret  voidTy  variable

# %%
with open('ir.txt', 'w', encoding='utf-8') as ir_out:
    with open('gir.txt', 'w', encoding='utf-8') as gir_out:
        for i, gi in get_test_samples():
            ir_out.write(i)
            ir_out.write('\n')
            gir_out.write(gi)
            gir_out.write('\n')
